# %%
import requests
import pandas as pd

# Liste des années à scraper
years = [2025,2024, 2023, 2022, 2021,2020]

# Boucle pour récupérer les classements des pilotes de chaque année
for year in years:
    url = f"http://ergast.com/api/f1/{year}/driverStandings.json"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        standings = data["MRData"].get("StandingsTable", {}).get("StandingsLists", [])
        
        if standings:
            standings = standings[0]["DriverStandings"]
            
            # Extraction des données
            drivers_data = []
            for driver in standings:
                position = driver["position"]
                name = f"{driver['Driver']['givenName']} {driver['Driver']['familyName']}"
                team = driver["Constructors"][0]["name"]
                points = driver["points"]
                wins = driver["wins"]
                drivers_data.append([position, name, team, points, wins])

            # Stockage en DataFrame
            df = pd.DataFrame(drivers_data, columns=["Position", "Pilote", "Équipe", "Points", "Victoires"])
            
            # Sauvegarde CSV
            filename = f"data/classement/classement_f1_{year}.csv"
            df.to_csv(filename, index=False)
            
            print(f"Données du classement pour {year} enregistrées dans {filename}")
            print(df)
        else:
            print(f"Aucun classement disponible pour {year}")
    else:
        print(f"Erreur de connexion à l'API Ergast pour l'année {year}")
# Out:
# Aucun classement disponible pour 2025
# Données du classement pour 2024 enregistrées dans data/classement/classement_f1_2024.csv
#    Position            Pilote          Équipe Points Victoires
# 0         1    Max Verstappen        Red Bull    437         9
# 1         2      Lando Norris         McLaren    374         4
# 2         3   Charles Leclerc         Ferrari    356         3
# 3         4     Oscar Piastri         McLaren    292         2
# 4         5      Carlos Sainz         Ferrari    290         2
# 5         6    George Russell        Mercedes    245         2
# 6         7    Lewis Hamilton        Mercedes    223         2
# 7         8      Sergio Pérez        Red Bull    152         0
# 8         9   Fernando Alonso    Aston Martin     70         0
# 9        10      Pierre Gasly  Alpine F1 Team     42         0
# 10       11   Nico Hülkenberg    Haas F1 Team     41         0
# 11       12      Yuki Tsunoda      RB F1 Team     30         0
# 12       13      Lance Stroll    Aston Martin     24         0
# 13       14      Esteban Ocon  Alpine F1 Team     23         0
# 14       15   Kevin Magnussen    Haas F1 Team     16         0
# 15       16   Alexander Albon        Williams     12         0
# 16       17  Daniel Ricciardo      RB F1 Team     12         0
# 17       18    Oliver Bearman         Ferrari      7         0
# 18       19  Franco Colapinto        Williams      5         0
# 19       20       Guanyu Zhou          Sauber      4         0
# 20       21       Liam Lawson      RB F1 Team      4         0
# 21       22   Valtteri Bottas          Sauber      0         0
# 22       23    Logan Sargeant        Williams      0         0
# 23       24       Jack Doohan  Alpine F1 Team      0         0
# Données du classement pour 2023 enregistrées dans data/classement/classement_f1_2023.csv
#    Position            Pilote          Équipe Points Victoires
# 0         1    Max Verstappen        Red Bull    575        19
# 1         2      Sergio Pérez        Red Bull    285         2
# 2         3    Lewis Hamilton        Mercedes    234         0
# 3         4   Fernando Alonso    Aston Martin    206         0
# 4         5   Charles Leclerc         Ferrari    206         0
# 5         6      Lando Norris         McLaren    205         0
# 6         7      Carlos Sainz         Ferrari    200         1
# 7         8    George Russell        Mercedes    175         0
# 8         9     Oscar Piastri         McLaren     97         0
# 9        10      Lance Stroll    Aston Martin     74         0
# 10       11      Pierre Gasly  Alpine F1 Team     62         0
# 11       12      Esteban Ocon  Alpine F1 Team     58         0
# 12       13   Alexander Albon        Williams     27         0
# 13       14      Yuki Tsunoda      AlphaTauri     17         0
# 14       15   Valtteri Bottas      Alfa Romeo     10         0
# 15       16   Nico Hülkenberg    Haas F1 Team      9         0
# 16       17  Daniel Ricciardo      AlphaTauri      6         0
# 17       18       Guanyu Zhou      Alfa Romeo      6         0
# 18       19   Kevin Magnussen    Haas F1 Team      3         0
# 19       20       Liam Lawson      AlphaTauri      2         0
# 20       21    Logan Sargeant        Williams      1         0
# 21       22     Nyck de Vries      AlphaTauri      0         0
# Données du classement pour 2022 enregistrées dans data/classement/classement_f1_2022.csv
#    Position            Pilote          Équipe Points Victoires
# 0         1    Max Verstappen        Red Bull    454        15
# 1         2   Charles Leclerc         Ferrari    308         3
# 2         3      Sergio Pérez        Red Bull    305         2
# 3         4    George Russell        Mercedes    275         1
# 4         5      Carlos Sainz         Ferrari    246         1
# 5         6    Lewis Hamilton        Mercedes    240         0
# 6         7      Lando Norris         McLaren    122         0
# 7         8      Esteban Ocon  Alpine F1 Team     92         0
# 8         9   Fernando Alonso  Alpine F1 Team     81         0
# 9        10   Valtteri Bottas      Alfa Romeo     49         0
# 10       11  Daniel Ricciardo         McLaren     37         0
# 11       12  Sebastian Vettel    Aston Martin     37         0
# 12       13   Kevin Magnussen    Haas F1 Team     25         0
# 13       14      Pierre Gasly      AlphaTauri     23         0
# 14       15      Lance Stroll    Aston Martin     18         0
# 15       16   Mick Schumacher    Haas F1 Team     12         0
# 16       17      Yuki Tsunoda      AlphaTauri     12         0
# 17       18       Guanyu Zhou      Alfa Romeo      6         0
# 18       19   Alexander Albon        Williams      4         0
# 19       20   Nicholas Latifi        Williams      2         0
# 20       21     Nyck de Vries        Williams      2         0
# 21       22   Nico Hülkenberg    Aston Martin      0         0
# Données du classement pour 2021 enregistrées dans data/classement/classement_f1_2021.csv
#    Position              Pilote          Équipe Points Victoires
# 0         1      Max Verstappen        Red Bull  395.5        10
# 1         2      Lewis Hamilton        Mercedes  387.5         8
# 2         3     Valtteri Bottas        Mercedes    226         1
# 3         4        Sergio Pérez        Red Bull    190         1
# 4         5        Carlos Sainz         Ferrari  164.5         0
# 5         6        Lando Norris         McLaren    160         0
# 6         7     Charles Leclerc         Ferrari    159         0
# 7         8    Daniel Ricciardo         McLaren    115         1
# 8         9        Pierre Gasly      AlphaTauri    110         0
# 9        10     Fernando Alonso  Alpine F1 Team     81         0
# 10       11        Esteban Ocon  Alpine F1 Team     74         1
# 11       12    Sebastian Vettel    Aston Martin     43         0
# 12       13        Lance Stroll    Aston Martin     34         0
# 13       14        Yuki Tsunoda      AlphaTauri     32         0
# 14       15      George Russell        Williams     16         0
# 15       16      Kimi Räikkönen      Alfa Romeo     10         0
# 16       17     Nicholas Latifi        Williams      7         0
# 17       18  Antonio Giovinazzi      Alfa Romeo      3         0
# 18       19     Mick Schumacher    Haas F1 Team      0         0
# 19       20       Robert Kubica      Alfa Romeo      0         0
# 20       21      Nikita Mazepin    Haas F1 Team      0         0
# Données du classement pour 2020 enregistrées dans data/classement/classement_f1_2020.csv
#    Position              Pilote        Équipe Points Victoires
# 0         1      Lewis Hamilton      Mercedes    347        11
# 1         2     Valtteri Bottas      Mercedes    223         2
# 2         3      Max Verstappen      Red Bull    214         2
# 3         4        Sergio Pérez  Racing Point    125         1
# 4         5    Daniel Ricciardo       Renault    119         0
# 5         6        Carlos Sainz       McLaren    105         0
# 6         7     Alexander Albon      Red Bull    105         0
# 7         8     Charles Leclerc       Ferrari     98         0
# 8         9        Lando Norris       McLaren     97         0
# 9        10        Pierre Gasly    AlphaTauri     75         1
# 10       11        Lance Stroll  Racing Point     75         0
# 11       12        Esteban Ocon       Renault     62         0
# 12       13    Sebastian Vettel       Ferrari     33         0
# 13       14        Daniil Kvyat    AlphaTauri     32         0
# 14       15     Nico Hülkenberg  Racing Point     10         0
# 15       16      Kimi Räikkönen    Alfa Romeo      4         0
# 16       17  Antonio Giovinazzi    Alfa Romeo      4         0
# 17       18      George Russell      Williams      3         0
# 18       19     Romain Grosjean  Haas F1 Team      2         0
# 19       20     Kevin Magnussen  Haas F1 Team      1         0
# 20       21     Nicholas Latifi      Williams      0         0
# 21       22         Jack Aitken      Williams      0         0
# 22       23   Pietro Fittipaldi  Haas F1 Team      0         0

# %%
import requests
import pandas as pd

# Boucle pour récupérer les circuits de chaque année
for year in years:
    url = f"http://ergast.com/api/f1/{year}/circuits.json"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        circuits = data["MRData"].get("CircuitTable", {}).get("Circuits", [])
        
        if circuits:
            # Extraction des données
            circuits_data = []
            for circuit in circuits:
                name = circuit["circuitName"]
                location = circuit["Location"]["locality"]
                country = circuit["Location"]["country"]
                url = circuit["url"]
                circuits_data.append([name, location, country, url])

            # Stockage en DataFrame
            df = pd.DataFrame(circuits_data, columns=["Circuit", "Ville", "Pays", "Lien"])
            
            # Sauvegarde CSV
            filename = f"data/circuits/circuits_f1_{year}.csv"
            df.to_csv(filename, index=False)
            
            print(f"Données des circuits pour {year} enregistrées dans {filename}")
            print(df)
        else:
            print(f"Aucun circuit disponible pour {year}")
    else:
        print(f"Erreur de connexion à l'API Ergast pour l'année {year}")
# Out:
# Données des circuits pour 2024 enregistrées dans data/circuits/circuits_f1_2024.csv
#                            Circuit        Ville           Pays  \
# 0   Albert Park Grand Prix Circuit    Melbourne      Australia
# 1          Circuit of the Americas       Austin            USA
# 2    Bahrain International Circuit       Sakhir        Bahrain
# 3                Baku City Circuit         Baku     Azerbaijan
# 4   Circuit de Barcelona-Catalunya     Montmeló          Spain
# 5                      Hungaroring     Budapest        Hungary
# 6    Autodromo Enzo e Dino Ferrari        Imola          Italy
# 7       Autódromo José Carlos Pace    São Paulo         Brazil
# 8          Jeddah Corniche Circuit       Jeddah   Saudi Arabia
# 9     Losail International Circuit    Al Daayen          Qatar
# 10       Marina Bay Street Circuit   Marina Bay      Singapore
# 11   Miami International Autodrome        Miami            USA
# 12               Circuit de Monaco  Monte-Carlo         Monaco
# 13    Autodromo Nazionale di Monza        Monza          Italy
# 14                   Red Bull Ring    Spielberg        Austria
# 15    Autódromo Hermanos Rodríguez  Mexico City         Mexico
# 16  Shanghai International Circuit     Shanghai          China
# 17             Silverstone Circuit  Silverstone             UK
# 18    Circuit de Spa-Francorchamps          Spa        Belgium
# 19                  Suzuka Circuit       Suzuka          Japan
# 20  Las Vegas Strip Street Circuit    Las Vegas  United States
# 21       Circuit Gilles Villeneuve     Montreal         Canada
# 22              Yas Marina Circuit    Abu Dhabi            UAE
# 23          Circuit Park Zandvoort    Zandvoort    Netherlands
#
#                                                  Lien
# 0   http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1   http://en.wikipedia.org/wiki/Circuit_of_the_Am...
# 2   http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3      http://en.wikipedia.org/wiki/Baku_City_Circuit
# 4   http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 5            http://en.wikipedia.org/wiki/Hungaroring
# 6   http://en.wikipedia.org/wiki/Autodromo_Enzo_e_...
# 7   http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Jo...
# 8   http://en.wikipedia.org/wiki/Jeddah_Street_Cir...
# 9   http://en.wikipedia.org/wiki/Losail_Internatio...
# 10  http://en.wikipedia.org/wiki/Marina_Bay_Street...
# 11  http://en.wikipedia.org/wiki/Miami_Internation...
# 12     http://en.wikipedia.org/wiki/Circuit_de_Monaco
# 13  http://en.wikipedia.org/wiki/Autodromo_Naziona...
# 14         http://en.wikipedia.org/wiki/Red_Bull_Ring
# 15  http://en.wikipedia.org/wiki/Aut%C3%B3dromo_He...
# 16  http://en.wikipedia.org/wiki/Shanghai_Internat...
# 17   http://en.wikipedia.org/wiki/Silverstone_Circuit
# 18  http://en.wikipedia.org/wiki/Circuit_de_Spa-Fr...
# 19        http://en.wikipedia.org/wiki/Suzuka_Circuit
# 20  https://en.wikipedia.org/wiki/Las_Vegas_Grand_...
# 21  http://en.wikipedia.org/wiki/Circuit_Gilles_Vi...
# 22    http://en.wikipedia.org/wiki/Yas_Marina_Circuit
# 23     http://en.wikipedia.org/wiki/Circuit_Zandvoort
# Données des circuits pour 2023 enregistrées dans data/circuits/circuits_f1_2023.csv
#                            Circuit        Ville           Pays  \
# 0   Albert Park Grand Prix Circuit    Melbourne      Australia
# 1          Circuit of the Americas       Austin            USA
# 2    Bahrain International Circuit       Sakhir        Bahrain
# 3                Baku City Circuit         Baku     Azerbaijan
# 4   Circuit de Barcelona-Catalunya     Montmeló          Spain
# 5                      Hungaroring     Budapest        Hungary
# 6       Autódromo José Carlos Pace    São Paulo         Brazil
# 7          Jeddah Corniche Circuit       Jeddah   Saudi Arabia
# 8     Losail International Circuit    Al Daayen          Qatar
# 9        Marina Bay Street Circuit   Marina Bay      Singapore
# 10   Miami International Autodrome        Miami            USA
# 11               Circuit de Monaco  Monte-Carlo         Monaco
# 12    Autodromo Nazionale di Monza        Monza          Italy
# 13                   Red Bull Ring    Spielberg        Austria
# 14    Autódromo Hermanos Rodríguez  Mexico City         Mexico
# 15             Silverstone Circuit  Silverstone             UK
# 16    Circuit de Spa-Francorchamps          Spa        Belgium
# 17                  Suzuka Circuit       Suzuka          Japan
# 18  Las Vegas Strip Street Circuit    Las Vegas  United States
# 19       Circuit Gilles Villeneuve     Montreal         Canada
# 20              Yas Marina Circuit    Abu Dhabi            UAE
# 21          Circuit Park Zandvoort    Zandvoort    Netherlands
#
#                                                  Lien
# 0   http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1   http://en.wikipedia.org/wiki/Circuit_of_the_Am...
# 2   http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3      http://en.wikipedia.org/wiki/Baku_City_Circuit
# 4   http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 5            http://en.wikipedia.org/wiki/Hungaroring
# 6   http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Jo...
# 7   http://en.wikipedia.org/wiki/Jeddah_Street_Cir...
# 8   http://en.wikipedia.org/wiki/Losail_Internatio...
# 9   http://en.wikipedia.org/wiki/Marina_Bay_Street...
# 10  http://en.wikipedia.org/wiki/Miami_Internation...
# 11     http://en.wikipedia.org/wiki/Circuit_de_Monaco
# 12  http://en.wikipedia.org/wiki/Autodromo_Naziona...
# 13         http://en.wikipedia.org/wiki/Red_Bull_Ring
# 14  http://en.wikipedia.org/wiki/Aut%C3%B3dromo_He...
# 15   http://en.wikipedia.org/wiki/Silverstone_Circuit
# 16  http://en.wikipedia.org/wiki/Circuit_de_Spa-Fr...
# 17        http://en.wikipedia.org/wiki/Suzuka_Circuit
# 18  https://en.wikipedia.org/wiki/Las_Vegas_Grand_...
# 19  http://en.wikipedia.org/wiki/Circuit_Gilles_Vi...
# 20    http://en.wikipedia.org/wiki/Yas_Marina_Circuit
# 21     http://en.wikipedia.org/wiki/Circuit_Zandvoort
# Données des circuits pour 2022 enregistrées dans data/circuits/circuits_f1_2022.csv
#                            Circuit         Ville          Pays  \
# 0   Albert Park Grand Prix Circuit     Melbourne     Australia
# 1          Circuit of the Americas        Austin           USA
# 2    Bahrain International Circuit        Sakhir       Bahrain
# 3                Baku City Circuit          Baku    Azerbaijan
# 4   Circuit de Barcelona-Catalunya      Montmeló         Spain
# 5                      Hungaroring      Budapest       Hungary
# 6    Autodromo Enzo e Dino Ferrari         Imola         Italy
# 7       Autódromo José Carlos Pace     São Paulo        Brazil
# 8          Jeddah Corniche Circuit        Jeddah  Saudi Arabia
# 9        Marina Bay Street Circuit    Marina Bay     Singapore
# 10   Miami International Autodrome         Miami           USA
# 11               Circuit de Monaco   Monte-Carlo        Monaco
# 12    Autodromo Nazionale di Monza         Monza         Italy
# 13                   Red Bull Ring     Spielberg       Austria
# 14             Circuit Paul Ricard  Le Castellet        France
# 15    Autódromo Hermanos Rodríguez   Mexico City        Mexico
# 16             Silverstone Circuit   Silverstone            UK
# 17    Circuit de Spa-Francorchamps           Spa       Belgium
# 18                  Suzuka Circuit        Suzuka         Japan
# 19       Circuit Gilles Villeneuve      Montreal        Canada
# 20              Yas Marina Circuit     Abu Dhabi           UAE
# 21          Circuit Park Zandvoort     Zandvoort   Netherlands
#
#                                                  Lien
# 0   http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1   http://en.wikipedia.org/wiki/Circuit_of_the_Am...
# 2   http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3      http://en.wikipedia.org/wiki/Baku_City_Circuit
# 4   http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 5            http://en.wikipedia.org/wiki/Hungaroring
# 6   http://en.wikipedia.org/wiki/Autodromo_Enzo_e_...
# 7   http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Jo...
# 8   http://en.wikipedia.org/wiki/Jeddah_Street_Cir...
# 9   http://en.wikipedia.org/wiki/Marina_Bay_Street...
# 10  http://en.wikipedia.org/wiki/Miami_Internation...
# 11     http://en.wikipedia.org/wiki/Circuit_de_Monaco
# 12  http://en.wikipedia.org/wiki/Autodromo_Naziona...
# 13         http://en.wikipedia.org/wiki/Red_Bull_Ring
# 14   http://en.wikipedia.org/wiki/Paul_Ricard_Circuit
# 15  http://en.wikipedia.org/wiki/Aut%C3%B3dromo_He...
# 16   http://en.wikipedia.org/wiki/Silverstone_Circuit
# 17  http://en.wikipedia.org/wiki/Circuit_de_Spa-Fr...
# 18        http://en.wikipedia.org/wiki/Suzuka_Circuit
# 19  http://en.wikipedia.org/wiki/Circuit_Gilles_Vi...
# 20    http://en.wikipedia.org/wiki/Yas_Marina_Circuit
# 21     http://en.wikipedia.org/wiki/Circuit_Zandvoort
# Données des circuits pour 2021 enregistrées dans data/circuits/circuits_f1_2021.csv
#                                Circuit         Ville          Pays  \
# 0              Circuit of the Americas        Austin           USA
# 1        Bahrain International Circuit        Sakhir       Bahrain
# 2                    Baku City Circuit          Baku    Azerbaijan
# 3       Circuit de Barcelona-Catalunya      Montmeló         Spain
# 4                          Hungaroring      Budapest       Hungary
# 5        Autodromo Enzo e Dino Ferrari         Imola         Italy
# 6           Autódromo José Carlos Pace     São Paulo        Brazil
# 7                        Istanbul Park      Istanbul        Turkey
# 8              Jeddah Corniche Circuit        Jeddah  Saudi Arabia
# 9         Losail International Circuit     Al Daayen         Qatar
# 10                   Circuit de Monaco   Monte-Carlo        Monaco
# 11        Autodromo Nazionale di Monza         Monza         Italy
# 12  Autódromo Internacional do Algarve      Portimão      Portugal
# 13                       Red Bull Ring     Spielberg       Austria
# 14                 Circuit Paul Ricard  Le Castellet        France
# 15        Autódromo Hermanos Rodríguez   Mexico City        Mexico
# 16                 Silverstone Circuit   Silverstone            UK
# 17                      Sochi Autodrom         Sochi        Russia
# 18        Circuit de Spa-Francorchamps           Spa       Belgium
# 19                  Yas Marina Circuit     Abu Dhabi           UAE
# 20              Circuit Park Zandvoort     Zandvoort   Netherlands
#
#                                                  Lien
# 0   http://en.wikipedia.org/wiki/Circuit_of_the_Am...
# 1   http://en.wikipedia.org/wiki/Bahrain_Internati...
# 2      http://en.wikipedia.org/wiki/Baku_City_Circuit
# 3   http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 4            http://en.wikipedia.org/wiki/Hungaroring
# 5   http://en.wikipedia.org/wiki/Autodromo_Enzo_e_...
# 6   http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Jo...
# 7          http://en.wikipedia.org/wiki/Istanbul_Park
# 8   http://en.wikipedia.org/wiki/Jeddah_Street_Cir...
# 9   http://en.wikipedia.org/wiki/Losail_Internatio...
# 10     http://en.wikipedia.org/wiki/Circuit_de_Monaco
# 11  http://en.wikipedia.org/wiki/Autodromo_Naziona...
# 12  http://en.wikipedia.org/wiki/Algarve_Internati...
# 13         http://en.wikipedia.org/wiki/Red_Bull_Ring
# 14   http://en.wikipedia.org/wiki/Paul_Ricard_Circuit
# 15  http://en.wikipedia.org/wiki/Aut%C3%B3dromo_He...
# 16   http://en.wikipedia.org/wiki/Silverstone_Circuit
# 17        http://en.wikipedia.org/wiki/Sochi_Autodrom
# 18  http://en.wikipedia.org/wiki/Circuit_de_Spa-Fr...
# 19    http://en.wikipedia.org/wiki/Yas_Marina_Circuit
# 20     http://en.wikipedia.org/wiki/Circuit_Zandvoort
# Données des circuits pour 2020 enregistrées dans data/circuits/circuits_f1_2020.csv
#                                  Circuit        Ville      Pays  \
# 0          Bahrain International Circuit       Sakhir   Bahrain
# 1         Circuit de Barcelona-Catalunya     Montmeló     Spain
# 2                            Hungaroring     Budapest   Hungary
# 3          Autodromo Enzo e Dino Ferrari        Imola     Italy
# 4                          Istanbul Park     Istanbul    Turkey
# 5           Autodromo Nazionale di Monza        Monza     Italy
# 6   Autodromo Internazionale del Mugello      Mugello     Italy
# 7                            Nürburgring      Nürburg   Germany
# 8     Autódromo Internacional do Algarve     Portimão  Portugal
# 9                          Red Bull Ring    Spielberg   Austria
# 10                   Silverstone Circuit  Silverstone        UK
# 11                        Sochi Autodrom        Sochi    Russia
# 12          Circuit de Spa-Francorchamps          Spa   Belgium
# 13                    Yas Marina Circuit    Abu Dhabi       UAE
#
#                                                  Lien
# 0   http://en.wikipedia.org/wiki/Bahrain_Internati...
# 1   http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 2            http://en.wikipedia.org/wiki/Hungaroring
# 3   http://en.wikipedia.org/wiki/Autodromo_Enzo_e_...
# 4          http://en.wikipedia.org/wiki/Istanbul_Park
# 5   http://en.wikipedia.org/wiki/Autodromo_Naziona...
# 6        http://en.wikipedia.org/wiki/Mugello_Circuit
# 7       http://en.wikipedia.org/wiki/N%C3%BCrburgring
# 8   http://en.wikipedia.org/wiki/Algarve_Internati...
# 9          http://en.wikipedia.org/wiki/Red_Bull_Ring
# 10   http://en.wikipedia.org/wiki/Silverstone_Circuit
# 11        http://en.wikipedia.org/wiki/Sochi_Autodrom
# 12  http://en.wikipedia.org/wiki/Circuit_de_Spa-Fr...
# 13    http://en.wikipedia.org/wiki/Yas_Marina_Circuit

# %%
for year in years:
    url = f"http://ergast.com/api/f1/{year}/constructors.json"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        constructors = data["MRData"].get("ConstructorTable", {}).get("Constructors", [])
        
        if constructors:
            # Extraction des données
            constructors_data = []
            for constructor in constructors:
                constructor_id = constructor["constructorId"]
                name = constructor["name"]
                nationality = constructor["nationality"]
                url = constructor["url"]
                constructors_data.append([constructor_id, name, nationality, url])

            # Stockage en DataFrame
            df = pd.DataFrame(constructors_data, columns=["ID", "Nom", "Nationalité", "Lien"])
            
            # Sauvegarde CSV
            filename = f"data/constructeurs/constructeurs_f1_{year}.csv"
            df.to_csv(filename, index=False)
            
            print(f"Données des constructeurs pour {year} enregistrées dans {filename}")
            print(df)
        else:
            print(f"Aucun constructeur disponible pour {year}")
    else:
        print(f"Erreur de connexion à l'API Ergast pour l'année {year}")
# Out:
# Aucun constructeur disponible pour 2025
# Données des constructeurs pour 2024 enregistrées dans data/constructeurs/constructeurs_f1_2024.csv
#              ID             Nom Nationalité  \
# 0        alpine  Alpine F1 Team      French
# 1  aston_martin    Aston Martin     British
# 2       ferrari         Ferrari     Italian
# 3          haas    Haas F1 Team    American
# 4       mclaren         McLaren     British
# 5      mercedes        Mercedes      German
# 6            rb      RB F1 Team     Italian
# 7      red_bull        Red Bull    Austrian
# 8        sauber          Sauber       Swiss
# 9      williams        Williams     British
#
#                                                 Lien
# 0        http://en.wikipedia.org/wiki/Alpine_F1_Team
# 1  http://en.wikipedia.org/wiki/Aston_Martin_in_F...
# 2      http://en.wikipedia.org/wiki/Scuderia_Ferrari
# 3          http://en.wikipedia.org/wiki/Haas_F1_Team
# 4               http://en.wikipedia.org/wiki/McLaren
# 5  http://en.wikipedia.org/wiki/Mercedes-Benz_in_...
# 6   http://en.wikipedia.org/wiki/RB_Formula_One_Team
# 7       http://en.wikipedia.org/wiki/Red_Bull_Racing
# 8     http://en.wikipedia.org/wiki/Sauber_Motorsport
# 9  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# Données des constructeurs pour 2023 enregistrées dans data/constructeurs/constructeurs_f1_2023.csv
#              ID             Nom Nationalité  \
# 0          alfa      Alfa Romeo       Swiss
# 1    alphatauri      AlphaTauri     Italian
# 2        alpine  Alpine F1 Team      French
# 3  aston_martin    Aston Martin     British
# 4       ferrari         Ferrari     Italian
# 5          haas    Haas F1 Team    American
# 6       mclaren         McLaren     British
# 7      mercedes        Mercedes      German
# 8      red_bull        Red Bull    Austrian
# 9      williams        Williams     British
#
#                                                 Lien
# 0  http://en.wikipedia.org/wiki/Alfa_Romeo_in_For...
# 1   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# 2        http://en.wikipedia.org/wiki/Alpine_F1_Team
# 3  http://en.wikipedia.org/wiki/Aston_Martin_in_F...
# 4      http://en.wikipedia.org/wiki/Scuderia_Ferrari
# 5          http://en.wikipedia.org/wiki/Haas_F1_Team
# 6               http://en.wikipedia.org/wiki/McLaren
# 7  http://en.wikipedia.org/wiki/Mercedes-Benz_in_...
# 8       http://en.wikipedia.org/wiki/Red_Bull_Racing
# 9  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# Données des constructeurs pour 2022 enregistrées dans data/constructeurs/constructeurs_f1_2022.csv
#              ID             Nom Nationalité  \
# 0          alfa      Alfa Romeo       Swiss
# 1    alphatauri      AlphaTauri     Italian
# 2        alpine  Alpine F1 Team      French
# 3  aston_martin    Aston Martin     British
# 4       ferrari         Ferrari     Italian
# 5          haas    Haas F1 Team    American
# 6       mclaren         McLaren     British
# 7      mercedes        Mercedes      German
# 8      red_bull        Red Bull    Austrian
# 9      williams        Williams     British
#
#                                                 Lien
# 0  http://en.wikipedia.org/wiki/Alfa_Romeo_in_For...
# 1   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# 2        http://en.wikipedia.org/wiki/Alpine_F1_Team
# 3  http://en.wikipedia.org/wiki/Aston_Martin_in_F...
# 4      http://en.wikipedia.org/wiki/Scuderia_Ferrari
# 5          http://en.wikipedia.org/wiki/Haas_F1_Team
# 6               http://en.wikipedia.org/wiki/McLaren
# 7  http://en.wikipedia.org/wiki/Mercedes-Benz_in_...
# 8       http://en.wikipedia.org/wiki/Red_Bull_Racing
# 9  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# Données des constructeurs pour 2021 enregistrées dans data/constructeurs/constructeurs_f1_2021.csv
#              ID             Nom Nationalité  \
# 0          alfa      Alfa Romeo       Swiss
# 1    alphatauri      AlphaTauri     Italian
# 2        alpine  Alpine F1 Team      French
# 3  aston_martin    Aston Martin     British
# 4       ferrari         Ferrari     Italian
# 5          haas    Haas F1 Team    American
# 6       mclaren         McLaren     British
# 7      mercedes        Mercedes      German
# 8      red_bull        Red Bull    Austrian
# 9      williams        Williams     British
#
#                                                 Lien
# 0  http://en.wikipedia.org/wiki/Alfa_Romeo_in_For...
# 1   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# 2        http://en.wikipedia.org/wiki/Alpine_F1_Team
# 3  http://en.wikipedia.org/wiki/Aston_Martin_in_F...
# 4      http://en.wikipedia.org/wiki/Scuderia_Ferrari
# 5          http://en.wikipedia.org/wiki/Haas_F1_Team
# 6               http://en.wikipedia.org/wiki/McLaren
# 7  http://en.wikipedia.org/wiki/Mercedes-Benz_in_...
# 8       http://en.wikipedia.org/wiki/Red_Bull_Racing
# 9  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# Données des constructeurs pour 2020 enregistrées dans data/constructeurs/constructeurs_f1_2020.csv
#              ID           Nom Nationalité  \
# 0          alfa    Alfa Romeo       Swiss
# 1    alphatauri    AlphaTauri     Italian
# 2       ferrari       Ferrari     Italian
# 3          haas  Haas F1 Team    American
# 4       mclaren       McLaren     British
# 5      mercedes      Mercedes      German
# 6  racing_point  Racing Point     British
# 7      red_bull      Red Bull    Austrian
# 8       renault       Renault      French
# 9      williams      Williams     British
#
#                                                 Lien
# 0  http://en.wikipedia.org/wiki/Alfa_Romeo_in_For...
# 1   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# 2      http://en.wikipedia.org/wiki/Scuderia_Ferrari
# 3          http://en.wikipedia.org/wiki/Haas_F1_Team
# 4               http://en.wikipedia.org/wiki/McLaren
# 5  http://en.wikipedia.org/wiki/Mercedes-Benz_in_...
# 6  http://en.wikipedia.org/wiki/Racing_Point_F1_Team
# 7       http://en.wikipedia.org/wiki/Red_Bull_Racing
# 8  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 9  http://en.wikipedia.org/wiki/Williams_Grand_Pr...

# %%
for year in years:
    url = f"http://ergast.com/api/f1/{year}.json"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        races = data["MRData"].get("RaceTable", {}).get("Races", [])
        
        if races:
            # Extraction des données
            races_data = []
            for race in races:
                round_num = race["round"]
                race_name = race["raceName"]
                circuit_name = race["Circuit"]["circuitName"]
                locality = race["Circuit"]["Location"]["locality"]
                country = race["Circuit"]["Location"]["country"]
                date = race["date"]
                time = race.get("time", "N/A")
                races_data.append([round_num, race_name, circuit_name, locality, country, date, time])

            # Stockage en DataFrame
            df = pd.DataFrame(races_data, columns=["Manche", "Grand Prix", "Circuit", "Ville", "Pays", "Date", "Heure"])
            
            # Sauvegarde CSV
            filename = f"data/calendrier/calendrier_f1_{year}.csv"
            df.to_csv(filename, index=False)
            
            print(f"Calendrier des courses pour {year} enregistré dans {filename}")
            print(df)
        else:
            print(f"Aucune course disponible pour {year}")
    else:
        print(f"Erreur de connexion à l'API Ergast pour l'année {year}")
# Out:
# Aucune course disponible pour 2025
# Calendrier des courses pour 2024 enregistré dans data/calendrier/calendrier_f1_2024.csv
#    Manche                 Grand Prix                         Circuit  \
# 0       1         Bahrain Grand Prix   Bahrain International Circuit
# 1       2   Saudi Arabian Grand Prix         Jeddah Corniche Circuit
# 2       3      Australian Grand Prix  Albert Park Grand Prix Circuit
# 3       4        Japanese Grand Prix                  Suzuka Circuit
# 4       5         Chinese Grand Prix  Shanghai International Circuit
# 5       6           Miami Grand Prix   Miami International Autodrome
# 6       7  Emilia Romagna Grand Prix   Autodromo Enzo e Dino Ferrari
# 7       8          Monaco Grand Prix               Circuit de Monaco
# 8       9        Canadian Grand Prix       Circuit Gilles Villeneuve
# 9      10         Spanish Grand Prix  Circuit de Barcelona-Catalunya
# 10     11        Austrian Grand Prix                   Red Bull Ring
# 11     12         British Grand Prix             Silverstone Circuit
# 12     13       Hungarian Grand Prix                     Hungaroring
# 13     14         Belgian Grand Prix    Circuit de Spa-Francorchamps
# 14     15           Dutch Grand Prix          Circuit Park Zandvoort
# 15     16         Italian Grand Prix    Autodromo Nazionale di Monza
# 16     17      Azerbaijan Grand Prix               Baku City Circuit
# 17     18       Singapore Grand Prix       Marina Bay Street Circuit
# 18     19   United States Grand Prix         Circuit of the Americas
# 19     20     Mexico City Grand Prix    Autódromo Hermanos Rodríguez
# 20     21       São Paulo Grand Prix      Autódromo José Carlos Pace
# 21     22       Las Vegas Grand Prix  Las Vegas Strip Street Circuit
# 22     23           Qatar Grand Prix    Losail International Circuit
# 23     24       Abu Dhabi Grand Prix              Yas Marina Circuit
#
#           Ville           Pays        Date      Heure
# 0        Sakhir        Bahrain  2024-03-02  15:00:00Z
# 1        Jeddah   Saudi Arabia  2024-03-09  17:00:00Z
# 2     Melbourne      Australia  2024-03-24  04:00:00Z
# 3        Suzuka          Japan  2024-04-07  05:00:00Z
# 4      Shanghai          China  2024-04-21  07:00:00Z
# 5         Miami            USA  2024-05-05  20:00:00Z
# 6         Imola          Italy  2024-05-19  13:00:00Z
# 7   Monte-Carlo         Monaco  2024-05-26  13:00:00Z
# 8      Montreal         Canada  2024-06-09  18:00:00Z
# Calendrier des courses pour 2020 enregistré dans data/calendrier/calendrier_f1_2020.csv
#    Manche                   Grand Prix                               Circuit  \
# 0       1          Austrian Grand Prix                         Red Bull Ring
# 1       2           Styrian Grand Prix                         Red Bull Ring
# 2       3         Hungarian Grand Prix                           Hungaroring
# 3       4           British Grand Prix                   Silverstone Circuit
# 4       5  70th Anniversary Grand Prix                   Silverstone Circuit
# 5       6           Spanish Grand Prix        Circuit de Barcelona-Catalunya
# 6       7           Belgian Grand Prix          Circuit de Spa-Francorchamps
# 7       8           Italian Grand Prix          Autodromo Nazionale di Monza
# 8       9            Tuscan Grand Prix  Autodromo Internazionale del Mugello
# 9      10           Russian Grand Prix                        Sochi Autodrom
# 10     11             Eifel Grand Prix                           Nürburgring
# 11     12        Portuguese Grand Prix    Autódromo Internacional do Algarve
# 12     13    Emilia Romagna Grand Prix         Autodromo Enzo e Dino Ferrari
# 13     14           Turkish Grand Prix                         Istanbul Park
# 14     15           Bahrain Grand Prix         Bahrain International Circuit
# 15     16            Sakhir Grand Prix         Bahrain International Circuit
# 16     17         Abu Dhabi Grand Prix                    Yas Marina Circuit
#
#           Ville      Pays        Date      Heure
# 0     Spielberg   Austria  2020-07-05  13:10:00Z
# 1     Spielberg   Austria  2020-07-12  13:10:00Z
# 2      Budapest   Hungary  2020-07-19  13:10:00Z
# 3   Silverstone        UK  2020-08-02  13:10:00Z
# 4   Silverstone        UK  2020-08-09  13:10:00Z
# 5      Montmeló     Spain  2020-08-16  13:10:00Z
# 6           Spa   Belgium  2020-08-30  13:10:00Z
# 7         Monza     Italy  2020-09-06  13:10:00Z
# 8       Mugello     Italy  2020-09-13  13:10:00Z
# 9         Sochi    Russia  2020-09-27  11:10:00Z
# 10      Nürburg   Germany  2020-10-11  13:10:00Z
# 11     Portimão  Portugal  2020-10-25  12:10:00Z
# 12        Imola     Italy  2020-11-01  12:10:00Z
# 13     Istanbul    Turkey  2020-11-15  10:10:00Z
# 14       Sakhir   Bahrain  2020-11-29  14:10:00Z
# 15       Sakhir   Bahrain  2020-12-06  17:10:00Z
# 16    Abu Dhabi       UAE  2020-12-13  13:10:00Z

# %%
import os
import rasa
from flask import Flask, request, jsonify
from flask_cors import CORS

# Initialisation de l'application Flask
app = Flask(__name__)
CORS(app)

# Démarrer le modèle Rasa en mode serveur
os.system("rasa run --enable-api &")

# Fonction pour envoyer un message à Rasa et obtenir une réponse
def get_rasa_response(message):
    response = os.popen(f"curl -X POST http://localhost:5005/webhooks/rest/webhook -d '{{"message": "{message}"}}' -H 'Content-Type: application/json'").read()
    return response

# Endpoint pour gérer les requêtes utilisateur
@app.route("/chat", methods=["POST"])
def chat():
    data = request.get_json()
    user_message = data.get("message", "")
    response_text = get_rasa_response(user_message)
    return jsonify({"reply": response_text})

# Démarrer le serveur Flask
if __name__ == "__main__":
    app.run(debug=True, port=5000)
# Out:
#   Cell In[27], line 15
#     response = os.popen(f"curl -X POST http://localhost:5005/webhooks/rest/webhook -d '{{"message": "{message}"}}' -H 'Content-Type: application/json'").read()
#                         ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
